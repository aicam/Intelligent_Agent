# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.histogram([1, 1.3, 1.7, 2, 2.5, 3], 3)
# Out:
# (array([2, 2, 2]), array([1.        , 1.66666667, 2.33333333, 3.        ]))

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins = np.histogram(s, 300, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
from Agent import Agent
a = Agent(20)
g = a.generate_guess()
plt.plot(g[0], g[1])
plt.show()

# %%
count2 = 1/(6 * np.sqrt(2 * np.pi)) * np.exp( - (g[0])**2 / (2 * 6**2) )

# %%
a.Sigma = 8
g = a.generate_guess()
plt.bar(g[0][:300], g[2])
plt.plot(g[0], count2, 'r')
plt.plot(g[0], g[1], 'g')

# %%
si = 9
count2 = 1/(si * np.sqrt(2 * np.pi)) * np.exp( - (g[0])**2 / (2 * si**2) )
np.var(g[2] - count2[:300])
# Out:
# 4.4436073680612785e-05
