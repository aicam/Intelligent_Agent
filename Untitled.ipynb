# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.histogram([1, 1.3, 1.7, 2, 2.5, 3], 3)
# Out:
# (array([2, 2, 2]), array([1.        , 1.66666667, 2.33333333, 3.        ]))

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)
count, bins = np.histogram(s, 300, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
from Agent import Agent
a = Agent(20)
g = a.generate_guess()
plt.plot(g[0], g[1])
plt.show()

# %%
s = np.random.normal(0, 3.8, 2000)
_, bins = np.histogram(s, 300, density=True)
plt.plot(bins, 1/(3.8 * np.sqrt(2 * np.pi)) * np.exp( - (bins)**2 / (2 * 3.8**2)))
