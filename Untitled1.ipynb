# %%
import numpy as np
from Agent import Agent
import matplotlib.pyplot as plt

# %%
from Crowd_Wisdom import CrowdWisdom

# %%
c = CrowdWisdom()

# %%
a = Agent()

# %%
int(a.evaluate_sigma(0.216667051974484)*(10**9))
# Out:
# 3454702757

# %%
a.Answer = 6.2

# %%
a.Sigma = 6.7

# %%
r, b =a.generate_guess()
ideal = np.array(1/(10 * np.sqrt(2 * np.pi)) * np.exp( - (r)**2 / (2 * 10**2)))
plt.plot(r,b, 'b.')
plt.plot(r, ideal)
plt.show()

# %%
c.optimize()

# %%
sigmas = [s.Sigma for s in c.agents]

# %%
np.mean(sigmas)
# Out:
# 0.411322282855349

# %%
plt.hist(sorted(sigmas))
# Out:
# (array([399.,   0.,   0., 200.,   0.,   0.,   2., 397.,   1.,   1.]),
#  array([0.05951228, 0.15264866, 0.24578503, 0.33892141, 0.43205778,
#         0.52519416, 0.61833053, 0.71146691, 0.80460328, 0.89773966,
#         0.99087603]),
#  <a list of 10 Patch objects>)
